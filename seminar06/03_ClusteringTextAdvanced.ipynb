# %% [markdown]
# # Продвинутые методы кластеризации текстов

# %% [markdown]
# Будем использовать библиотеку gensim: https://radimrehurek.com/gensim/ – обновите вирутальное окружение

# %%
import gensim

# %% [markdown]
# ### Откроем датасет

# %%
from sklearn.datasets import fetch_20newsgroups

twenty = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))

# %% [markdown]
# ### Выполним токенизацию с помощью nltk

# %%
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/tylorn/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk import word_tokenize
from collections import Counter
import string

docs = []
for text in twenty.data:
    tokens = [w.lower() for w in word_tokenize(text) if not w in string.punctuation]
    docs.append(tokens)

# %%
print('Токенизированный текст:')
print(docs[4])
# Out:
# Токенизированный текст:
# ['1', 'i', 'have', 'an', 'old', 'jasmine', 'drive', 'which', 'i', 'can', 'not', 'use', 'with', 'my', 'new', 'system', 'my', 'understanding', 'is', 'that', 'i', 'have', 'to', 'upsate', 'the', 'driver', 'with', 'a', 'more', 'modern', 'one', 'in', 'order', 'to', 'gain', 'compatability', 'with', 'system', '7.0.1.', 'does', 'anyone', 'know', 'of', 'an', 'inexpensive', 'program', 'to', 'do', 'this', 'i', 'have', 'seen', 'formatters', 'for', '20', 'buit', 'have', 'no', 'idea', 'if', 'they', 'will', 'work', '2', 'i', 'have', 'another', 'ancient', 'device', 'this', 'one', 'a', 'tape', 'drive', 'for', 'which', 'the', 'back', 'utility', 'freezes', 'the', 'system', 'if', 'i', 'try', 'to', 'use', 'it', 'the', 'drive', 'is', 'a', 'jasmine', 'direct', 'tape', 'bought', 'used', 'for', '150', 'w/', '6', 'tapes', 'techmar', 'mechanism', 'essentially', 'i', 'have', 'the', 'same', 'question', 'as', 'above', 'anyone', 'know', 'of', 'an', 'inexpensive', 'beckup', 'utility', 'i', 'can', 'use', 'with', 'system', '7.0.1']

# %% [markdown]
# ### Удалим стоп-слова из текстов

# %% [markdown]
# Эти слова часто встречаются в текстах, вне зависимости от тематики. Поэтому в данной задаче они нам будут только мешаться.

# %%
from nltk.corpus import stopwords
stop = set(stopwords.words('english'))
print(stop)
# Out:
# {'these', 'what', 'should', 'won', 'most', 'there', 'me', "that'll", 'down', "hasn't", 'own', 'she', "mightn't", "should've", 'to', 'am', 'does', 'some', 'or', 'shouldn', "you'd", 'so', 'their', 'i', 'more', 'can', 're', 'her', 'which', 'do', 'under', 'them', 'hers', 'having', 'couldn', 'if', 'themselves', 'our', 'your', 've', 'and', 'an', 'above', 'after', 'needn', 'itself', 'doing', 'not', 'himself', 'for', 'are', 'd', 'ain', 'they', 'below', 'again', 'hadn', 'those', 'now', 'mustn', "you're", 'with', 'against', "won't", 'off', 'have', "wasn't", 'we', 'any', 'by', 'yourselves', "aren't", 'further', 'until', 'a', 'nor', 'ours', 't', 'doesn', 'all', 'very', 'while', "you'll", 'haven', "don't", 'over', "shouldn't", "weren't", 'weren', 'it', 'then', 'you', 'whom', "haven't", 'yourself', 'is', 'but', "isn't", 'mightn', 'at', 'yours', 'll', "didn't", 'isn', 'he', 'same', "she's", 'herself', 'in', 'such', 'how', 'up', "you've", 'will', 'o', 'be', 'during', 'wasn', 'its', 'other', 'been', 'about', 'm', 'than', 'when', 'hasn', 'shan', 'wouldn', 'no', 'between', 'being', 'into', 'were', 'from', "doesn't", 'too', 'did', 'once', 'ma', 's', 'y', 'him', "it's", "hadn't", "wouldn't", 'theirs', 'the', 'each', 'aren', 'on', 'through', 'this', 'ourselves', 'here', "shan't", 'few', 'because', 'didn', 'both', 'was', 'only', 'who', 'of', 'my', 'before', "needn't", 'his', 'where', 'myself', 'as', 'had', 'just', 'that', 'has', 'don', "couldn't", 'why', "mustn't", 'out'}

# %%
new_docs = []
for tokens in docs:
    new_docs.append([token for token in tokens if not token in stop])
docs = new_docs

# %%
print(docs[4])
# Out:
# ['1', 'old', 'jasmine', 'drive', 'use', 'new', 'system', 'understanding', 'upsate', 'driver', 'modern', 'one', 'order', 'gain', 'compatability', 'system', '7.0.1.', 'anyone', 'know', 'inexpensive', 'program', 'seen', 'formatters', '20', 'buit', 'idea', 'work', '2', 'another', 'ancient', 'device', 'one', 'tape', 'drive', 'back', 'utility', 'freezes', 'system', 'try', 'use', 'drive', 'jasmine', 'direct', 'tape', 'bought', 'used', '150', 'w/', '6', 'tapes', 'techmar', 'mechanism', 'essentially', 'question', 'anyone', 'know', 'inexpensive', 'beckup', 'utility', 'use', 'system', '7.0.1']

# %% [markdown]
# ### Построим словарь по корпусу

# %%
from gensim import corpora

dictionary = corpora.Dictionary(docs)
print(dictionary)
# Out:
# Dictionary(198027 unique tokens: ['actually', 'also', 'anyway', 'bashers', 'beat']...)

# %%
# Отфильтруем словарь
dictionary.filter_extremes(no_below=2, no_above=1, keep_n=300000)
print(dictionary)
# Out:
# Dictionary(60483 unique tokens: ['actually', 'also', 'anyway', 'bashers', 'beat']...)

# %%
new_doc = "Hello world"
new_vec = dictionary.doc2bow(new_doc.lower().split())

# %%
new_vec
# Out:
# [(770, 1), (4686, 1)]

# %%
corpus = [dictionary.doc2bow(doc) for doc in docs]

# %%
from gensim import models

tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

# %% [markdown]
# ### LSI

# %%
lsi = models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=10)

# %%
corpus_lsi = lsi[corpus_tfidf]

# %%
lsi.print_topics(num_topics=10, num_words=20)
# Out:
# [(0,
#   '0.987*"--" + 0.036*"\'\'" + 0.030*"``" + 0.026*"..." + 0.023*"n\'t" + 0.023*"\'s" + 0.019*"1" + 0.017*"would" + 0.016*"one" + 0.016*"0" + 0.014*"people" + 0.014*"get" + 0.014*"know" + 0.014*"2" + 0.014*"like" + 0.013*"\'m" + 0.012*"use" + 0.012*"think" + 0.012*"also" + 0.011*"time"'),
#  (1,
#   '-0.214*"\'\'" + -0.184*"``" + -0.166*"n\'t" + -0.162*"..." + -0.154*"\'s" + 0.151*"--" + -0.140*"would" + -0.119*"one" + -0.112*"people" + -0.103*"like" + -0.100*"know" + -0.096*"get" + -0.095*"think" + -0.094*"god" + -0.090*"\'m" + -0.086*"could" + -0.078*"good" + -0.075*"also" + -0.075*"use" + -0.074*"time"'),
#  (2,
#   '0.234*"god" + 0.215*"\'\'" + 0.208*"``" + -0.204*"windows" + -0.173*"thanks" + -0.153*"drive" + -0.151*"card" + -0.116*"please" + -0.109*"dos" + 0.106*"jesus" + 0.105*"people" + -0.105*"anyone" + -0.101*"file" + -0.093*"software" + -0.089*"program" + -0.088*"disk" + -0.088*"system" + -0.087*"advance" + -0.086*"pc" + -0.084*"scsi"'),
#  (3,
#   '-0.655*"..." + 0.261*"god" + 0.178*"\'\'" + -0.154*"game" + 0.151*"``" + 0.116*"windows" + 0.114*"jesus" + -0.103*"team" + -0.090*"games" + -0.076*"year" + -0.074*"hockey" + 0.072*"x" + 0.072*"bible" + -0.071*"car" + 0.068*"file" + -0.067*".." + 0.061*"dos" + 0.061*"card" + 0.059*"christ" + -0.058*"\'s"'),
#  (4,
#   '0.644*"..." + 0.250*"god" + -0.160*"game" + 0.159*"windows" + -0.151*"1" + -0.127*"0" + -0.112*"2" + -0.102*"games" + 0.100*"jesus" + -0.099*"team" + -0.097*"year" + 0.095*"thanks" + 0.089*"file" + -0.088*"3" + -0.080*"drive" + 0.076*"\'\'" + 0.073*"``" + -0.069*"4" + -0.069*"\'s" + 0.065*"bible"'),
#  (5,
#   '-0.437*"\'\'" + -0.331*"``" + -0.300*"1" + -0.284*"0" + -0.218*"..." + -0.201*"2" + -0.137*"3" + -0.121*"drive" + -0.117*"4" + 0.112*"n\'t" + 0.111*"thanks" + 0.105*"would" + 0.100*"know" + 0.098*"god" + 0.097*"anyone" + -0.096*"5" + 0.093*"\'m" + -0.077*"6" + -0.077*"x" + 0.077*"could"'),
#  (6,
#   '0.428*"god" + 0.190*"drive" + 0.175*"jesus" + -0.173*"\'\'" + 0.171*"1" + -0.165*"``" + -0.156*"key" + -0.152*"government" + 0.137*"game" + 0.130*"2" + -0.126*"encryption" + 0.123*"0" + -0.109*"chip" + -0.105*"clipper" + 0.096*"scsi" + 0.094*"games" + 0.093*"card" + -0.093*"keys" + -0.091*"x" + 0.090*"bible"'),
#  (7,
#   '-0.392*"drive" + -0.221*"scsi" + 0.208*"0" + 0.175*"game" + -0.163*"ide" + 0.160*"x" + 0.157*"1" + 0.136*"thanks" + 0.133*"windows" + -0.132*"controller" + -0.125*"drives" + 0.122*"please" + -0.121*"disk" + -0.118*"hard" + 0.109*"games" + -0.102*"..." + 0.102*"file" + -0.101*"card" + -0.096*"bus" + 0.093*"team"'),
#  (8,
#   '0.370*"windows" + -0.284*"please" + -0.243*"thanks" + 0.199*"dos" + -0.155*"e-mail" + 0.149*"file" + -0.131*"anyone" + -0.128*"1" + -0.124*"email" + 0.117*"game" + 0.116*"window" + -0.107*"send" + -0.105*"0" + -0.102*"address" + -0.097*"advance" + -0.097*"interested" + 0.093*"3.1" + -0.092*"info" + -0.091*"information" + -0.087*"list"'),
#  (9,
#   '-0.352*"\'\'" + -0.287*"``" + 0.239*"1" + 0.234*"0" + 0.225*"key" + 0.215*"god" + 0.171*"chip" + 0.143*"2" + -0.142*"thanks" + 0.142*"encryption" + -0.141*"please" + 0.135*"clipper" + -0.131*"drive" + 0.124*"keys" + 0.099*"government" + 0.094*"..." + 0.093*"escrow" + 0.090*"3" + 0.089*"system" + 0.089*"use"')]

# %%
lsi.show_topic(6, topn=30)
# Out:
# [('god', 0.4280338535388315),
#  ('drive', 0.18953382098086954),
#  ('jesus', 0.17469414588976204),
#  ("''", -0.17314524952045643),
#  ('1', 0.17074046105858176),
#  ('``', -0.16517557979445016),
#  ('key', -0.15632796434255716),
#  ('government', -0.15178672181800817),
#  ('game', 0.1365068147692675),
#  ('2', 0.12960960231628751),
#  ('encryption', -0.12566678219629587),
#  ('0', 0.12347349406420842),
#  ('chip', -0.10918863740833173),
#  ('clipper', -0.10516412592876272),
#  ('scsi', 0.09569790300650378),
#  ('games', 0.09443961243787354),
#  ('card', 0.09318871005429562),
#  ('keys', -0.09270574873104238),
#  ('x', -0.09082989489227028),
#  ('bible', 0.08994847137919082),
#  ('christ', 0.08532847234827436),
#  ('3', 0.0802715376362297),
#  ('faith', 0.07597612076700522),
#  ('ide', 0.07577522898844595),
#  ('file', -0.07526622045519835),
#  ('sin', 0.07369835959384831),
#  ('controller', 0.06953142423576955),
#  ('escrow', -0.06800387819384468),
#  ('4', 0.06763677094950721),
#  ('christian', 0.06733144639559693)]

# %% [markdown]
# ### LDA

# %%
lda = models.LdaModel(corpus, id2word=dictionary, num_topics=20, passes=10)

# %%
corpus_lda = lda[corpus]

# %%
lda.print_topics(20)
# Out:
# [(0,
#   '0.008*"one" + 0.008*"car" + 0.007*"\'s" + 0.007*"would" + 0.006*"like" + 0.006*"n\'t" + 0.005*"used" + 0.005*"also" + 0.005*"power" + 0.005*"use"'),
#  (1,
#   '0.676*"--" + 0.004*"\'\'" + 0.002*"_/" + 0.002*"file" + 0.002*"tor" + 0.002*"det" + 0.001*"bos" + 0.001*"``" + 0.001*"1" + 0.001*"pts"'),
#  (2,
#   '0.022*"drive" + 0.012*"disk" + 0.010*"hard" + 0.010*"price" + 0.009*"sale" + 0.009*"please" + 0.008*"new" + 0.008*"drives" + 0.008*"offer" + 0.008*"scsi"'),
#  (3,
#   '0.035*"n\'t" + 0.025*"\'s" + 0.015*"would" + 0.013*"\'\'" + 0.012*"one" + 0.011*"``" + 0.010*"like" + 0.010*"think" + 0.009*"know" + 0.009*"get"'),
#  (4,
#   '0.021*"game" + 0.017*"team" + 0.015*"\'s" + 0.014*"year" + 0.013*"games" + 0.009*"season" + 0.009*"hockey" + 0.008*"last" + 0.008*"play" + 0.007*"players"'),
#  (5,
#   '0.020*"card" + 0.010*"mac" + 0.010*"monitor" + 0.009*"video" + 0.009*"board" + 0.009*"db" + 0.008*"apple" + 0.008*"memory" + 0.007*"modem" + 0.007*"bus"'),
#  (6,
#   '0.009*"\'\'" + 0.008*"space" + 0.007*"``" + 0.007*"use" + 0.006*"medical" + 0.006*"health" + 0.005*"also" + 0.005*"launch" + 0.004*"research" + 0.004*"number"'),
#  (7,
#   '0.015*"55.0" + 0.014*"widget" + 0.010*"window" + 0.008*"***" + 0.008*"value" + 0.007*"-1" + 0.007*"0" + 0.006*"event" + 0.006*"visual" + 0.006*"int"'),
#  (8,
#   '0.147*"x" + 0.038*"\'\'" + 0.029*"``" + 0.016*"c" + 0.011*"*/" + 0.011*"/*" + 0.009*"file" + 0.007*"entry" + 0.007*"echo" + 0.007*"string"'),
#  (9,
#   '0.236*"..." + 0.015*".." + 0.006*"wings" + 0.005*"ed" + 0.005*"leafs" + 0.005*"captain" + 0.004*"greece" + 0.003*"deleted" + 0.003*"greek" + 0.003*"traded"'),
#  (10,
#   '0.067*"1" + 0.055*"2" + 0.044*"0" + 0.036*"3" + 0.031*"4" + 0.023*"25" + 0.021*"5" + 0.018*"6" + 0.014*"7" + 0.011*"8"'),
#  (11,
#   '0.032*"\'\'" + 0.027*"``" + 0.008*"people" + 0.007*"god" + 0.007*"one" + 0.006*"\'s" + 0.006*"would" + 0.005*"believe" + 0.004*"many" + 0.004*"may"'),
#  (12,
#   '0.019*"key" + 0.013*"\'\'" + 0.011*"``" + 0.010*"use" + 0.009*"encryption" + 0.008*"chip" + 0.008*"keys" + 0.006*"security" + 0.006*"message" + 0.006*"system"'),
#  (13,
#   '0.258*"\'ax" + 0.086*"\'\'" + 0.030*"``" + 0.019*"max" + 0.017*"p" + 0.017*"r" + 0.016*"g" + 0.015*"q" + 0.012*"n" + 0.011*"7"'),
#  (14,
#   '0.010*"university" + 0.008*"information" + 0.007*"space" + 0.006*"ripem" + 0.006*"earth" + 0.006*"\'s" + 0.005*"research" + 0.005*"kinsey" + 0.005*"book" + 0.004*"national"'),
#  (15,
#   '0.016*"windows" + 0.014*"thanks" + 0.012*"anyone" + 0.011*"please" + 0.010*"would" + 0.010*"use" + 0.010*"know" + 0.009*"get" + 0.009*"help" + 0.009*"using"'),
#  (16,
#   '0.012*"\'s" + 0.007*"government" + 0.007*"people" + 0.006*"q" + 0.006*"would" + 0.005*"president" + 0.005*"mr." + 0.004*"said" + 0.004*"gun" + 0.004*"\'\'"'),
#  (17,
#   '0.016*"image" + 0.009*"available" + 0.009*"file" + 0.008*"version" + 0.007*"\'s" + 0.007*"\'\'" + 0.007*"software" + 0.007*"ftp" + 0.007*"data" + 0.006*"files"'),
#  (18,
#   '0.012*"1" + 0.010*"vs" + 0.007*"1st" + 0.005*"new" + 0.005*"art" + 0.005*"cover" + 0.005*"appears" + 0.004*"2" + 0.004*"\'s" + 0.004*"diet"'),
#  (19,
#   '0.031*"\'\'" + 0.026*"``" + 0.022*"god" + 0.011*"jesus" + 0.008*"christ" + 0.006*"armenian" + 0.006*"lord" + 0.006*"armenians" + 0.005*"turkish" + 0.005*"sin"')]

# %%
lda.show_topic(6, topn=30)
# Out:
# [("''", 0.008547938),
#  ('space', 0.00807677),
#  ('``', 0.0071484935),
#  ('use', 0.006715425),
#  ('medical', 0.0060977456),
#  ('health', 0.00551356),
#  ('also', 0.0045722793),
#  ('launch', 0.0045270007),
#  ('research', 0.0044693006),
#  ('number', 0.0044362526),
#  ('program', 0.003945844),
#  ('disease', 0.0038403259),
#  ('may', 0.003762252),
#  ('drug', 0.0037017886),
#  ('years', 0.0036456059),
#  ("'s", 0.0034633416),
#  ('patients', 0.0033457),
#  ('aids', 0.003273301),
#  ('1993', 0.0031918862),
#  ('rate', 0.0031273786),
#  ('study', 0.003089018),
#  ('age', 0.003006778),
#  ('cancer', 0.0029866612),
#  ('reported', 0.0029654019),
#  ('data', 0.002962463),
#  ('shuttle', 0.0029469475),
#  ('nasa', 0.0029422925),
#  ('treatment', 0.002883637),
#  ('april', 0.0028814469),
#  ('low', 0.0028571167)]

# %% [markdown]
# ### Similarities

# %%
from gensim import similarities

index = similarities.MatrixSimilarity(corpus_lsi)
# Out:
# /home/tylorn/envs/dmia/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
doc = docs[0]
vec_bow = dictionary.doc2bow(doc)
vec_lsi = lsi[tfidf[vec_bow]]
vec_lda = lda[vec_bow]
print(vec_lda)
# Out:
# [(3, 0.5968805), (4, 0.26077282), (7, 0.070963666), (16, 0.039297562), (19, 0.021371132)]

# %%
sims = index[vec_lsi] # ищет похожие вектора
print(list(enumerate(sims)))
# Out:
# [(0, 1.0), (1, -0.016020186), (2, 0.24476933), (3, -0.13402167), (4, 0.018832482), (5, 0.52422357), (6, 0.30389732), (7, 0.9549281), (8, 0.8806156), (9, 0.0059505217), (10, 0.19897309), (11, -0.016295858), (12, 0.39718354), (13, 0.12901296), (14, -0.0032772087), (15, 0.17627211), (16, -0.018927034), (17, 0.21632572), (18, 0.14980677), (19, 0.5041377), (20, 0.6059541), (21, 0.19476672), (22, 0.4055552), (23, 0.72389776), (24, 0.67794764), (25, 0.4351244), (26, 0.5370468), (27, 0.032690026), (28, 0.07486583), (29, 0.19004422), (30, 0.47575748), (31, 0.14667453), (32, 0.0076875687), (33, 0.86102754), (34, 0.55279696), (35, 0.18732095), (36, 0.38883895), (37, 0.14185339), (38, 0.48589802), (39, 0.428982), (40, 0.66759175), (41, 0.26409405), (42, 0.62091035), (43, -0.06595177), (44, 0.079058126), (45, 0.037893936), (46, 0.11635432), (47, 0.6117934), (48, 0.31287283), (49, -0.092176564), (50, 0.25913638), (51, 0.57340825), (52, 0.0030790581), (53, -0.21169293), (54, 0.5895906), (55, 0.61649716), (56, 0.27385235), (57, 0.37575376), (58, 0.35613978), (59, 0.506723), (60, 0.7602687), (61, 0.68269855), (62, 0.022013016), (63, -0.051095225), (64, 0.50209737), (65, 0.40496194), (66, 0.9021256), (67, 0.2193223), (68, 0.017355189), (69, 0.306172), (70, 0.09685621), (71, 0.7042661), (72, 0.36576048), (73, 0.04199419), (74, 0.5288201), (75, 0.675957), (76, 0.95861834), (77, 0.17590794), (78, 0.4730687), (79, 0.96139705), (80, 0.49443427), (81, 0.7902877), (82, 0.15423723), (83, 0.33048), (84, 0.3158494), (85, 0.16880505), (86, 0.24263091), (87, 0.37467125), (88, 0.2352499), (89, 0.18461178), (90, 0.95986384), (91, 0.0), (92, 0.32167006), (93, 0.14773189), (94, 0.13917653), (95, 0.18810484), (96, 0.4084196), (97, 0.92011774), (98, 0.18965964), (99, -0.08798614), (100, 0.64586735), (101, 0.052011743), (102, 0.26649553), (103, -0.02651434), (104, 0.0), (105, 0.95300436), (106, 0.26113468), (107, 0.024668267), (108, 0.6001307), (109, -0.004953081), (110, 0.087198876), (111, 0.6747716), (112, 0.36493453), (113, 0.1329704), (114, 0.35772273), (115, 0.19542804), (116, 0.19372362), (117, 0.19014555), (118, 0.8703135), (119, 0.26733556), (120, 0.28581548), (121, 0.5379853), (122, 0.19166669), (123, 0.082294665), (124, 0.46182504), (125, 0.66322124), (126, 0.32871658), (127, 0.0), (128, 0.36700875), (129, 0.0015524626), (130, 0.09391429), (131, 0.17652339), (132, 0.3108341), (133, 0.84001464), (134, 0.18386438), (135, 0.0), (136, 0.31880158), (137, -0.12064195), (138, 0.29526427), (139, 0.0905661), (140, 0.22940171), (141, 0.40864757), (142, 0.30771548), (143, 0.24989149), (144, 0.22415093), (145, 0.34733874), (146, 0.29542553), (147, 0.14163662), (148, 0.716584), (149, 0.010273466), (150, 0.6343659), (151, 0.44858256), (152, 0.09318972), (153, 0.17664474), (154, 0.47981137), (155, 0.25940704), (156, 0.36395898), (157, 0.29046315), (158, 0.59302217), (159, 0.2072273), (160, 0.2524776), (161, 0.0), (162, 0.17901172), (163, 0.23835236), (164, 0.42014396), (165, 0.5272758), (166, 0.021610774), (167, 0.6094414), (168, 0.33697048), (169, 0.5691047), (170, 0.23124129), (171, 0.2316785), (172, 0.014144242), (173, 0.28475758), (174, -0.07659944), (175, 0.2658688), (176, 0.93216175), (177, 0.16793923), (178, 0.5330893), (179, 0.9924298), (180, 0.13139747), (181, 0.4301638), (182, 0.061521463), (183, 0.04934173), (184, 0.40412968), (185, 0.0), (186, 0.20628327), (187, 0.39993396), (188, 0.039785195), (189, 0.14421622), (190, 0.1268956), (191, -0.029614285), (192, 0.0), (193, 0.3655696), (194, 0.26914686), (195, 0.31144264), (196, 0.212842), (197, 0.24646392), (198, 0.4887131), (199, 0.10498625), (200, -0.091478206), (201, 0.17633775), (202, 0.40868372), (203, 0.43045968), (204, 0.30878583), (205, 0.5282346), (206, -0.14388707), (207, 0.28499743), (208, 0.30547032), (209, 0.55841666), (210, 0.7760031), (211, 0.25535968), (212, 0.5267821), (213, 0.19151273), (214, 0.5966996), (215, 0.39611423), (216, 0.028210148), (217, 0.55145967), (218, 0.5899073), (219, 0.0), ( ...

# %% [markdown]
# ### Опциональное задание

# %% [markdown]
# - Подобрать параметры, чтобы получить более интерпретируемую картинку
# - Избавиться от мусора в токенах (можно с помощью регулярных выражений)
